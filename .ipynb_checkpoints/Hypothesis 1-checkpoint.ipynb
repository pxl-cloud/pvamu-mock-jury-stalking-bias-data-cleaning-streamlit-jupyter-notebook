# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot
import scipy
import plotly
import seaborn as sns

# %%
df = pd.read_csv("mock-jury-stalking-data.csv")
df
# Out:
#      ATTN-CIV1-1  ATTN-CIV1-2  ATTN-CIV1-3  ATTN-CIV1-4  ATTN-CIV1-5  \
# 0            1.0          2.0          5.0          1.0          1.0
# 1            1.0          2.0          5.0          1.0          1.0
# 2            1.0          2.0          5.0          1.0          1.0
# 3            1.0          2.0          5.0          1.0          1.0
# 4            1.0          2.0          5.0          1.0          1.0
# ..           ...          ...          ...          ...          ...
# 211          NaN          NaN          NaN          NaN          NaN
# 212          NaN          NaN          NaN          NaN          NaN
# 213          NaN          NaN          NaN          NaN          NaN
# 214          NaN          NaN          NaN          NaN          NaN
# 215          NaN          NaN          NaN          NaN          NaN
#
#      ATTN-CIV1-6  ATTN-CIV1-7  DEC-RATE-CIV1  DEC-CIV1-1  \
# 0            2.0          1.0            7.0         1.0
# ...
